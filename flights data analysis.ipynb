# %%
import pandas as pd

# %%
raw_data = pd.read_csv('flights.csv')

# %%
raw_data
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0     2020      1           6          3   1057.0        1100   1432.0
# 1     2020      1           7          4   1056.0        1100   1426.0
# 2     2020      1           8          5   1055.0        1100   1445.0
# 3     2020      1           9          6   1102.0        1100   1433.0
# 4     2020      1          10          7   1240.0        1100   1631.0
# ...    ...    ...         ...        ...      ...         ...      ...
# 5549  2020     12          20          3   1619.0        1625   1719.0
# 5550  2020     12          21          4   1723.0        1625   1828.0
# 5551  2020     12          22          5   1652.0        1625   1756.0
# 5552  2020     12          23          6   1640.0        1625   1741.0
# 5553  2020     12          24          7   1657.0        1625   1757.0
#
#       CRSArrTime  ActualElapsedTime  CRSElapsedTime  ...  TaxiIn  TaxiOut  \
# ...

# %%
raw_data.shape
# Out:
# (5554, 26)

# %%
raw_data.isnull().sum()
# Out:
# Year                    0
# Month                   0
# DayofMonth              0
# DayOfWeek               0
# DepTime               194
# CRSDepTime              0
# ArrTime               197
# CRSArrTime              0
# ActualElapsedTime     208
# CRSElapsedTime          0
# AirTime               208
# ArrDelay              208
# DepDelay              194
# Origin                  0
# Dest                    0
# Distance                0
# TaxiIn                197
# TaxiOut               195
# Cancelled               0
# CancellationCode     5358
# Diverted                0
# CarrierDelay         4449
# WeatherDelay         4449
# NASDelay             4449
# SecurityDelay        4449
# LateAircraftDelay    4449
# dtype: int64

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5554 entries, 0 to 5553
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               5554 non-null   int64
#  1   Month              5554 non-null   int64
#  2   DayofMonth         5554 non-null   int64
#  3   DayOfWeek          5554 non-null   int64
#  4   DepTime            5360 non-null   float64
#  5   CRSDepTime         5554 non-null   int64
#  6   ArrTime            5357 non-null   float64
#  7   CRSArrTime         5554 non-null   int64
#  8   ActualElapsedTime  5346 non-null   float64
#  9   CRSElapsedTime     5554 non-null   int64
#  10  AirTime            5346 non-null   float64
#  11  ArrDelay           5346 non-null   float64
#  12  DepDelay           5360 non-null   float64
#  13  Origin             5554 non-null   object
#  14  Dest               5554 non-null   object
#  15  Distance           5554 non-null   int64
# ...

# %%
data = raw_data.copy()

# %%
#pd.options.display.max_columns = None
data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2020      1           6          3   1057.0        1100   1432.0
# 1  2020      1           7          4   1056.0        1100   1426.0
# 2  2020      1           8          5   1055.0        1100   1445.0
# 3  2020      1           9          6   1102.0        1100   1433.0
# 4  2020      1          10          7   1240.0        1100   1631.0
#
#    CRSArrTime  ActualElapsedTime  CRSElapsedTime  ...  TaxiIn  TaxiOut  \
# 0        1438              155.0             158  ...     8.0     15.0
# 1        1438              150.0             158  ...    10.0     14.0
# 2        1438              170.0             158  ...    14.0     21.0
# 3        1438              151.0             158  ...     9.0     13.0
# 4        1438              171.0             158  ...    14.0     20.0
#
#    Cancelled CancellationCode Diverted  CarrierDelay  WeatherDelay  NASDelay  \
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'ActualElapsedTime', 'CRSElapsedTime',
#        'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest', 'Distance',
#        'TaxiIn', 'TaxiOut', 'Cancelled', 'CancellationCode', 'Diverted',
#        'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay',
#        'LateAircraftDelay'],
#       dtype='object')

# %%
cols_with_na = data[['CancellationCode']]
df__no_null = data.drop(cols_with_na,axis=1)
df__no_null
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0     2020      1           6          3   1057.0        1100   1432.0
# 1     2020      1           7          4   1056.0        1100   1426.0
# 2     2020      1           8          5   1055.0        1100   1445.0
# 3     2020      1           9          6   1102.0        1100   1433.0
# 4     2020      1          10          7   1240.0        1100   1631.0
# ...    ...    ...         ...        ...      ...         ...      ...
# 5549  2020     12          20          3   1619.0        1625   1719.0
# 5550  2020     12          21          4   1723.0        1625   1828.0
# 5551  2020     12          22          5   1652.0        1625   1756.0
# 5552  2020     12          23          6   1640.0        1625   1741.0
# 5553  2020     12          24          7   1657.0        1625   1757.0
#
#       CRSArrTime  ActualElapsedTime  CRSElapsedTime  ...  Distance  TaxiIn  \
# ...

# %%
df__no_null.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'ActualElapsedTime', 'CRSElapsedTime',
#        'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest', 'Distance',
#        'TaxiIn', 'TaxiOut', 'Cancelled', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
import datetime as dt
df__no_null['DepTime'] = pd.to_datetime(df__no_null['DepTime'])

# %%
type(df__no_null['DepTime'])
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt
#plotting graphs  
#fig,ax = plt.subplots()
num_destinations=df__no_null['Dest'].nunique()
destinations=df__no_null['Dest'].unique()
destinations
dest_DTW = df__no_null['Dest'].groupby(df__no_null['Dest']=='DTW')
dest_JFK = df__no_null['Dest'].groupby(df__no_null['Dest']=='JFK')
dest_LAX = df__no_null['Dest'].groupby(df__no_null['Dest']=='LAX')
dest_DEN = df__no_null['Dest'].groupby(df__no_null['Dest']=='DEN')
type(dest_DEN)
#ax=plt.plot(df__no_null['ArrTime'],df__no_null['Year'])
#plt.show()
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
destinations
# Out:
# array(['DTW', 'DFW', 'JFK', 'SEA', 'ORD', 'SJC', 'STL', 'DCA', 'TPA',
#        'MIA', 'DEN', 'LAX', 'KOA', 'IAH', 'AUS', 'LAS', 'MCO', 'SLC',
#        'STT', 'BOS', 'FLL', 'SFO', 'HNL', 'OGG', 'TUL', 'PHL', 'SNA',
#        'IAD', 'LGA', 'RDU', 'EWR', 'RIC', 'PDX', 'CLT', 'ELP', 'SAN',
#        'SAT', 'MCI', 'BNA', 'PHX', 'ONT', 'TUS', 'SMF'], dtype=object)
